# %% [markdown]
# # Introduction to Matplotlib

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## More Style Options can be accessed here: https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html

# %% [markdown]
# # Simple Plots

# %%
plt.plot([1,2,3,4])

# %% [markdown]
# ## Sin Wave

# %%
import numpy as np
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x))

# %%
plt.plot(x, np.cos(x))

# %%
plt.plot(x, np.tan(x))

# %%
plt.plot(x, np.tanh(x))

# %%
plt.plot(x, np.sin(x), '-o')

# %% [markdown]
# ## Exponential Function

# %%
plt.plot(x, np.exp(x))

# %%
x = np.linspace(0, 15)

plt.plot(x, x)
plt.plot(x, 2*x+2, '--')
plt.plot(x, 3*x+6, '*')

# %%
plt.plot(x, x, linestyle = 'dashed')
plt.plot(x, 2*x+2, linestyle = 'solid')
plt.plot(x, 3*x+6, linestyle = 'dotted')

# %% [markdown]
# # Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title('A Sine Curve')
plt.xlabel('x')
plt.ylabel('sin(x)')
# Out:
# Text(0, 0.5, 'sin(x)')

# %% [markdown]
# # More Advanced Plotting

# %% [markdown]
# ## Scatter Plots

# %%
from sklearn.datasets import load_iris
iris = load_iris()
features = iris.data.T

plt.scatter(features[2], features[3], alpha=0.2, s=100, c=iris.target, cmap='viridis')

# %% [markdown]
# ## Bar Charts

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

langs = ['C', 'C++', 'Java', 'Python' ,'PHP']
students = [25, 46, 32, 12, 19]

ax.bar(langs, students, color='b', width=0.15)
plt.show()

# %% [markdown]
# ## Stacked Bar Charts

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

langs = ['C', 'C++', 'Java', 'Python' ,'PHP']
boys = [25, 46, 32, 12, 19]
girls = [28, 15, 42, 36, 37]

ax.bar(langs, boys, color='b', width=0.15)
ax.bar(langs, girls, color='r', width=0.15, bottom=boys)

plt.show()

# %% [markdown]
# ## Side-by-side Bar Chart

# %%
data = [[25, 46, 32, 12, 19],[28, 15, 42, 36, 37]]

x = np.arange(5)
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

ax.bar(x+0.0, data[0], color='b', width=0.15)
ax.bar(x+0.2, data[1], color='r', width=0.15)
plt.show()

# %% [markdown]
# ## Pie Charts

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

langs = ['C', 'C++', 'Java', 'Python' ,'PHP']
students = [25, 46, 32, 12, 19]

ax.pie(students, labels=langs, autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ## Histograms

# %%
x=np.random.randn(1000)

plt.hist(x, bins=20)
plt.show()

# %% [markdown]
# ## Box Plots

# %%
plt.boxplot(x)
plt.show()

# %% [markdown]
# ## Multiple Plots

# %%
fig, a = plt.subplots(2,2, figsize=(10,10))

x = np.arange(0,10)
a[0,0].plot(x, x*x)
a[0,0].set_title('Squared')

a[0,1].plot(x, np.sqrt(x))
a[0,1].set_title('Square root')

a[1,0].plot(x, np.exp(x))
a[1,0].set_title('Exponential')

a[1,1].plot(x, np.log10(x))
a[1,1].set_title('Log10')

plt.show()
# Out:
# /var/folders/6n/g06hphz56lg6q35x5z3yfbch0000gn/T/ipykernel_1612/2393861032.py:13: RuntimeWarning: divide by zero encountered in log10
#   a[1,1].plot(x, np.log10(x))

# %% [markdown]
# # Write a code to do the following:
# # 1. Create a pie chart the represents the distribution of the number of students in each lab of the Introduction to Data Science course. (You can get the data from Neptun)
# # 2. Create a figure with 2 rows and 2 columns:
# # a. Plot a sine wave in the first plot
# # b. Plot a cosine wave in the second plot
# # c. Plot a tangent wave in the third plot
# # d. Plot a cotangent wave in the fourth plot
# # e. Label the plots appropriately
# # f. Set the title of the figure to "Trigonometric Functions"
